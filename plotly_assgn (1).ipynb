# %%
#Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
#scatter plot for age and fare columns in the titanic dataset.

import seaborn as sns
import plotly.graph_objects as go

titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
fig=go.Figure(data=[go.Bar(x=titanic.age,y=titanic.fare)])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.
import seaborn as sns
import plotly.graph_objects as go

tips=sns.load_dataset('tips')
fig=go.Figure(data=[go.Box(x=tips)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
import plotly.subplots as sp
import plotly.express as px
import pandas as pd
import seaborn as sns

# Load the iris dataset from seaborn
iris = sns.load_dataset('iris')

# Create a scatter matrix plot using Plotly's make_subplots
fig = sp.make_subplots(rows=3, cols=3, subplot_titles=("Sepal Length vs. Sepal Width", "Sepal Length vs. Petal Length",
                                                    "Sepal Length vs. Petal Width", "Sepal Width vs. Petal Length",
                                                    "Sepal Width vs. Petal Width", "Petal Length vs. Petal Width"))

# Create scatter plots for each combination of features
colors = px.colors.qualitative.Set1  # You can choose a color palette
species = iris['species'].unique()
species_colors = {species[i]: colors[i] for i in range(len(species))}

for i in range(3):
    for j in range(3):
        x_col = iris.columns[i]
        y_col = iris.columns[j]
        for s in species:
            scatter_data = iris[iris['species'] == s]
            scatter = go.Scatter(x=scatter_data[x_col], y=scatter_data[y_col],
                                 mode='markers', name=s,
                                 marker=dict(color=species_colors[s]))
            fig.add_trace(scatter, row=i+1, col=j+1)

# Update axis labels
for i in range(1, 4):
    fig.update_xaxes(title_text=iris.columns[i - 1], row=3, col=i)
    fig.update_yaxes(title_text=iris.columns[i], row=i, col=1)

# Update layout
fig.update_layout(title="Scatter Matrix Plot of Iris Dataset",
                  height=800, width=800,
                  showlegend=True)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Q5. What is Distplot? Using Plotly express, plot a distplot

# %%
#The distplot figure factory displays a combination of statistical representations of numerical data, such as histogram, kernel density estimation or normal curve, and rug plot.
import plotly.express as px
df = px.data.tips()
fig = px.histogram(df, x="total_bill", y="tip", color="sex", marginal="rug",
                   hover_data=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
